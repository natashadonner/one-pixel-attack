# %% [markdown]
# # Report Laboration 1 – Group 12
#
# **Authors:**
# Natasha Donner

# %% [markdown]
# ## Method
#
# ### Task 1
#
# To perform this task we followed the guidlines in the preprocessing for deeplearning blog post.
